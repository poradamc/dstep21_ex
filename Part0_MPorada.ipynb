# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
## The data for this exercise can be found at https://data.oecd.org/healthres/health-spending.htm
## The dataset downloaded was a reduced dataset which looked only at "Total" cost as a "% of GDP" for the 
## years 1990-2020.  This reduced data set can be achieved by selecting these parameters in the dropdown menus
## on the website and downloaded "selected data".

## Load data from local drive (jupyter notebook and *.csv file are in same folder)

fname = "HC_spending.csv"

# %%
data = pd.read_csv(fname)

# %%
data
# Out:
#      LOCATION  INDICATOR SUBJECT MEASURE FREQUENCY  TIME  Value Flag Codes
# 0         AUS  HEALTHEXP     TOT  PC_GDP         A  1990  6.480        NaN
# 1         AUS  HEALTHEXP     TOT  PC_GDP         A  1991  6.776        NaN
# 2         AUS  HEALTHEXP     TOT  PC_GDP         A  1992  6.840        NaN
# 3         AUS  HEALTHEXP     TOT  PC_GDP         A  1993  6.857        NaN
# 4         AUS  HEALTHEXP     TOT  PC_GDP         A  1994  6.889        NaN
# ...       ...        ...     ...     ...       ...   ...    ...        ...
# 1244      ROU  HEALTHEXP     TOT  PC_GDP         A  2015  4.947        NaN
# 1245      ROU  HEALTHEXP     TOT  PC_GDP         A  2016  5.003        NaN
# 1246      ROU  HEALTHEXP     TOT  PC_GDP         A  2017  5.151        NaN
# 1247      ROU  HEALTHEXP     TOT  PC_GDP         A  2018  5.561        NaN
# 1248      ROU  HEALTHEXP     TOT  PC_GDP         A  2019  5.744        NaN
#
# [1249 rows x 8 columns]

# %%
## Select rows containing data for USA only
US_data = data[data["LOCATION"] == "USA"]

# %%
US_data
# Out:
#     LOCATION  INDICATOR SUBJECT MEASURE FREQUENCY  TIME   Value Flag Codes
# 864      USA  HEALTHEXP     TOT  PC_GDP         A  1990  11.239        NaN
# 865      USA  HEALTHEXP     TOT  PC_GDP         A  1991  11.920        NaN
# 866      USA  HEALTHEXP     TOT  PC_GDP         A  1992  12.197        NaN
# 867      USA  HEALTHEXP     TOT  PC_GDP         A  1993  12.455        NaN
# 868      USA  HEALTHEXP     TOT  PC_GDP         A  1994  12.383        NaN
# 869      USA  HEALTHEXP     TOT  PC_GDP         A  1995  12.501        NaN
# 870      USA  HEALTHEXP     TOT  PC_GDP         A  1996  12.472        NaN
# 871      USA  HEALTHEXP     TOT  PC_GDP         A  1997  12.379        NaN
# 872      USA  HEALTHEXP     TOT  PC_GDP         A  1998  12.362        NaN
# 873      USA  HEALTHEXP     TOT  PC_GDP         A  1999  12.348        NaN
# 874      USA  HEALTHEXP     TOT  PC_GDP         A  2000  12.484        NaN
# ...

# %%
## Select independent variable, year, by extracting the "TIME" column from the reduced dataset "USA_data"
year = US_data["TIME"]

# %%
year
# Out:
# 864    1990
# 865    1991
# 866    1992
# 867    1993
# 868    1994
# 869    1995
# 870    1996
# 871    1997
# 872    1998
# 873    1999
# 874    2000
# 875    2001
# 876    2002
# 877    2003
# 878    2004
# 879    2005
# 880    2006
# 881    2007
# 882    2008
# 883    2009
# 884    2010
# 885    2011
# 886    2012
# 887    2013
# 888    2014
# 889    2015
# 890    2016
# 891    2017
# 892    2018
# 893    2019
# Name: TIME, dtype: int64

# %%
## Select dependent variable, cost, by extracting the "Value" column from the reduced dataset "USA_data"
cost = US_data["Value"]

# %%
cost
# Out:
# 864    11.239
# 865    11.920
# 866    12.197
# 867    12.455
# 868    12.383
# 869    12.501
# 870    12.472
# 871    12.379
# 872    12.362
# 873    12.348
# 874    12.484
# 875    13.164
# 876    13.982
# 877    14.499
# 878    14.595
# 879    14.605
# 880    14.718
# 881    14.939
# 882    15.267
# 883    16.234
# 884    16.259
# 885    16.199
# 886    16.175
# 887    16.065
# 888    16.253
# 889    16.524
# 890    16.844
# 891    16.806
# 892    16.687
# 893    16.767
# Name: Value, dtype: float64

# %%
## Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 5))

##  Add a line to that plot 
lin, = ax.plot(year, cost, color="k")

## Add gridlines
ax.grid(linestyle="--")

## Add labels to the axes
xlab = ax.set_xlabel("Year", fontsize=14)
ylab = ax.set_ylabel("Percent of GDP", fontsize=14)

## Set the range for the x values
ax.set_xlim(year.min(), year.max())

## Increase tick label size
ax.tick_params(axis="both", labelsize=14)

# %% [markdown]
# Healthcare Spending as a Percent of GDP in the US 1990-2019
